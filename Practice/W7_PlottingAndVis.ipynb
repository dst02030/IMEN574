# %% [markdown]
# # Matplot

# %% [markdown]
# ## Example - matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(np.arange(10)) # np.arange(10): 0~9까지 리스트 리턴

# %% [markdown]
# ## Charting Library - bar()

# %%
plt.bar([0,1,2,3],[1.5,3.5,-2,1.6])
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(range(10), np.random.randn(10), width=1.0)
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ## Charting Library - plot()

# %%
plt.plot([1.5, 3.5, -2, 1.6])

# %%
from numpy.random import randn
plt.plot(randn(50).cumsum(), 'k--')

# %% [markdown]
# ## Charting Library - scatter()

# %%
plt.scatter(range(10), np.random.randn(10))

# %%
N = 50
x = np.random.rand(N)
y = np.random.randn(N)
colors = np.random.randn(N)

area = np.pi * (15 * np.random.rand(N))**2 # 0 to 15 point radii

plt.scatter(x, y, s = area, c = colors, alpha = 0.5)

# %% [markdown]
# ## Charting Library - boxplot()

# %%
import numpy as np
import matplotlib.pyplot as plt

# fake data
np.random.seed(937)
data = np.random.lognormal(size = (37, 4), mean = 1.5, sigma = 1.75)
labels = list('ABCD')
fs = 10 # fontsize

# demonstrate how to toggle the display of different elements:
fig, axes = plt.subplots(nrows = 1, ncols = 4, figsize = (8, 5), sharey = True)
axes[0].boxplot(data, labels = labels)
axes[0].set_title('Default', fontsize = fs)

axes[1].boxplot(data, labels = labels, showmeans = True)
axes[1].set_title('Showmeans = True', fontsize = fs)

axes[2].boxplot(data, labels = labels, showmeans = True, meanline = True)
axes[2].set_title('showmeans=True, /nmeanline = True', fontsize = fs)

axes[3].boxplot(data, labels = labels, showfliers = False)
axes[3].set_title('showfliers = False', fontsize = fs)

for ax in axes.flatten():
    ax.set_yscale('log')
    ax.set_yticklabels([])
    
fig.subplots_adjust(hspace = 0.4)
plt.show()

# %% [markdown]
# ## Example -subplot

# %%
fig = plt.figure()

# %%
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
fig

# %%
_ = ax1.hist(randn(100), bins = 20, color = 'k', alpha = 0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * randn(30))
ax3.plot(randn(50).cumsum(), 'k--')
fig

# %%
fig, axes = plt.subplots(2, 3)
axes[0, 1].plot(randn(50).cumsum(), 'k--')
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000159B869F5C0>,
# ...
#       dtype=object)

# %% [markdown]
# ## Adjusting the spacing around subplots

# %%
plt.subplots_adjust(left = None,bottom = None, right = None, top = None, wspace = None, hspace = None)

# %%
fig, axes = plt.subplots(2, 2, sharex = True, sharey = True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(randn(500), bins = 50, color = 'k', alpha = 0.5)
plt.subplots_adjust(wspace=0, hspace=0)

# %% [markdown]
# ## Line styles, colors, and markers

# %%
plt.figure()
fig, axes = plt.subplots(2, 2)
axes[0, 0].plot(randn(50).cumsum(), 'k--')
axes[0, 1].plot(randn(50).cumsum(), 'ko--')
axes[1, 0].plot(randn(20).cumsum(), linestyle = 'solid', color = 'k', marker = '+')
axes[1, 1].plot(randn(50).cumsum(), linestyle = 'dotted', color = 'g')
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000159B8C19240>,
# ...
#       dtype=object)

# %% [markdown]
# ## Draw style

# %%
data = randn(30).cumsum()
plt.plot(data, 'k--', label = 'Default')
plt.plot(data, 'k-', drawstyle = 'steps-post', label = 'steps-post')
plt.legend(loc = 'best')

# %% [markdown]
# ## Example: ticks, labels, and legends

# %%
fig = plt.figure(); ax = fig.add_subplot(1, 1,1)
ax.plot(randn(1000).cumsum())


ticks = ax.set_xticks([0, 250, 500, 750, 1000])
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'],
                           rotation = 30, fontsize = 'small')

ax.set_title('My first matplotlib plot')
ax.set_xlabel('Stages')
ax.set_ylabel('Values')
ax.set_xlim([0, 1200])
# Out:
# (0, 1200)

# %% [markdown]
# ## Example: adding legends

# %%
fig = plt.figure(); ax = fig.add_subplot(1, 1, 1)
ax.plot(randn(1000).cumsum(), 'k', label = 'one')
ax.plot(randn(1000).cumsum(), 'g--', label = 'two')
ax.plot(randn(1000).cumsum(), 'r.', label = 'three')

ax.legend(loc = 'best')

# %% [markdown]
# ## Annotations on a subplot

# %%
from datetime import datetime
import pandas as pd
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

data = pd.read_csv('./W7_data/spx.csv', index_col = 0, parse_dates = True)
spx = data['SPX']

spx.plot(ax = ax, style = 'k-')

crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 50),
                 xytext = (date, spx.asof(date) + 300),
                 arrowprops = dict(facecolor = 'red'),
                 horizontalalignment='left', verticalalignment = 'top')
    

# Zoom in on 2007-2010
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1900])

ax.set_title('Important dates in 2008-2009 financial crisis')
# Out:
# Text(0.5, 1.0, 'Important dates in 2008-2009 financial crisis')

# %% [markdown]
# ## Saving Plots to File

# %%
fig.savefig('figpath.svg')

# %%
fig.savefig('figpath.png', dpi = 400, bbox_inches = 'tight')

# %%
from io import BytesIO
buffer = BytesIO()
plt.savefig(buffer)
plot_data = buffer.getvalue()

# %% [markdown]
# # 3. Pandas

# %% [markdown]
# ## Plotting functions in pandas

# %%
from pandas import Series, DataFrame
import pandas as pd

# %% [markdown]
# ## Line Plots

# %%
s = Series(np.random.randn(10).cumsum(),
          index = np.arange(0, 100, 10))
s.plot()

# %%
s.plot(xlim = [-10, 100], xticks = [0, 30, 60, 90],
      yticks = np.arange(-2, 6, 2))

# %%
df = DataFrame(np.random.randn(10, 4).cumsum(0),
              columns = ['A', 'B', 'C', 'D'],
              index = np.arange(0, 100, 10))

df.plot()

# %%
df = DataFrame(np.random.randn(20, 4).cumsum(0),
              columns = ['A', 'B', 'C', 'D'],
              index = np.arange(0, 100, 5))
df.plot()

# %%
df.A.plot()
df.B.plot(secondary_y = True, style = 'g')

# %% [markdown]
# ## Bar Plots

# %%
fig, axes = plt.subplots(2, 1)
data = Series(np.random.rand(16), index = list('abcdefghijklmnop'))
data.plot(kind = 'bar', ax = axes[0], color = 'k', figsize = (6, 8), alpha = 0.7)
data.plot(kind = 'barh', ax = axes[1], color = 'k', figsize = (6, 8), alpha = 0.7)

# %%
df = DataFrame(np.random.rand(6, 4),
              index = ['one', 'two','three', 'four', 'five', 'six'],
              columns = pd.Index(['A', 'B', 'C', 'D'], name = 'Genus'))
df
df.plot(kind = 'bar')

# %%
df.plot(kind = 'barh', stacked = True, alpha = 0.5)

# %% [markdown]
# ## Histograms and Density Plots

# %%
tips = pd.read_csv('./W7_data/tips.csv')
tips['tip_pct'] = tips['tip'] / tips['total_bill']
tips['tip_pct'].hist(bins = 50)

# %%
df = pd.DataFrame({'a': np.random.randn(1000)+1, 'b': np.random.randn(1000),
                  'c': np.random.randn(1000)-1}, columns = ['a', 'b', 'c'])
plt.figure()
df.plot.hist(alpha = 0.5)

# %%
plt.figure()
df.plot.hist(stacked=True, bins = 20)

# %% [markdown]
# ## Histograms and Density Plots

# %%
tips['tip_pct'].plot(kind = 'kde')

# %%
tips = pd.read_csv('./W7_data/tips.csv')
tips['tip_pct'] = tips['tip'] / tips['total_bill']
tips['tip_pct'].hist(bins = 50, normed = True)
tips['tip_pct'].plot(kind = 'kde')
# Out:
# C:\Users\SmartHinJ\Anaconda3\envs\SmartHinJ\lib\site-packages\pandas\plotting\_matplotlib\hist.py:309: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   ax.hist(values, bins=bins, **kwds)

# %%
cormp1 = np.random.normal(0, 1, size = 200) # N(0, 1)
cormp2 = np.random.normal(10, 2, size = 200) # N(10, 4)

values = Series(np.concatenate([cormp1, cormp2]))
values.hist(bins = 100, alpha = 0.3, color = 'k', density = True)
values.plot(kind = 'kde', style = 'r--')

# %% [markdown]
# ## Scatter Plots

# %%
macro = pd.read_csv('./W7_data/macrodata.csv')
data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]
trans_data = np.log(data).diff().dropna()

# %%
plt.figure()
plt.scatter(trans_data['m1'], trans_data['unemp'])
plt.title('Changes in log %s vs. log %s' % ('m1', 'unemp'))
# Out:
# Text(0.5, 1.0, 'Changes in log m1 vs. log unemp')

# %% [markdown]
# ## Scatter Plot Matrix

# %%
pd.plotting.scatter_matrix(trans_data, diagonal = 'kde', color = 'k', alpha = 0.3, figsize = (8, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000159BCC51048>,
# ...
#       dtype=object)

# %% [markdown]
# ## Area Plot

# %%
df = pd.DataFrame(np.random.rand(10, 4),
                 columns = ['a', 'b', 'c', 'd'])

df.plot.area();

# %%
df.plot.area(stacked = False)

# %% [markdown]
# ## Hexagonal Bin Plots

# %%
macro = pd.read_csv('./W7_data/macrodata.csv')
data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]
data.plot.hexbin(x = 'm1', y = 'unemp', gridsize = 15, figsize = (8, 8))

# %%
data.plot.hexbin(x = 'm1', y = 'unemp', C = 'cpi', gridsize = 15)

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns = ['a', 'b'])
df['b'] = df['b'] + np.arange(1000)
df.plot.hexbin(x = 'a', y= 'b', gridsize = 25, figsize = (8, 8))

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns = ['a', 'b'])
df['b'] = df['b'] + np.arange(1000)
df.plot.hexbin(x = 'a', y= 'b', gridsize = 50, figsize = (8, 8))

# %% [markdown]
# ## Pie Plot

# %%
series = pd.Series(3 * np.random.rand(4),
                  index = ['a', 'b', 'c', 'd'], name = 'series')
series
# Out:
# a    2.117332
# b    1.753444
# c    1.487269
# d    1.137462
# Name: series, dtype: float64

# %%
series.plot.pie(figsize = (6, 6))

# %%
df = pd.DataFrame(3 * np.random.rand(4, 2),
                 index = ['a', 'b', 'c', 'd'], columns = ['x', 'y'])
df
# Out:
#           x         y
# a  2.954981  0.236088
# b  2.868345  1.552046
# c  2.046500  1.309257
# d  2.534284  0.199647

# %%
df.plot.pie(subplots = True, figsize = (8, 4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000159BE929B00>,
# ...
#       dtype=object)

# %%
series.plot.pie(labels = ['AA', 'BB', 'CC', 'DD'],
               colors = ['r', 'g', 'b', 'c'],
               autopct = '%.2f', fontsize = 20, figsize = (6, 6))

# %%
series = pd.Series([0.1] * 4,
                  index = ['a', 'b', 'c', 'd'],
                  name = 'series')
series
# Out:
# a    0.1
# b    0.1
# c    0.1
# d    0.1
# Name: series, dtype: float64

# %%
series.plot.pie(figsize = (6, 6))

# %% [markdown]
# ## Parallel Coordinates

# %%
from pandas.plotting import parallel_coordinates
data = pd.read_csv('./W7_data/iris.csv')
data
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
parallel_coordinates(data, "Name")
